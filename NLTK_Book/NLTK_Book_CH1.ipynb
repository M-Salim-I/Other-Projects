# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Salim-I/Other-Projects/blob/main/NLTK_Book/NLTK_Book_CH1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code and text used from the online book:
# https://www.nltk.org/book/

# %%
import nltk
nltk.download() # d, book, q
from nltk.book import *
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> book
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package brown to /root/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package chat80 to /root/nltk_data...
#        |   Package chat80 is already up-to-date!
#        | Downloading package cmudict to /root/nltk_data...
#        |   Package cmudict is already up-to-date!
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Package conll2000 is already up-to-date!
#        | Downloading package conll2002 to /root/nltk_data...
# ...

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %% [markdown]
# # searching a word with its context in a book (in every possible instance the word is used in the book)

# %% [markdown]
# A concordance view shows us every occurrence of a given word, together with some context.

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text2.concordance('affection')
# Out:
# Displaying 25 of 79 matches:
# , however , and , as a mark of his affection for the three girls , he left them
# t . It was very well known that no affection was ever supposed to exist between
# deration of politeness or maternal affection on the side of the former , the tw
# d the suspicion -- the hope of his affection for me may warrant , without impru
# hich forbade the indulgence of his affection . She knew that his mother neither
# rd she gave one with still greater affection . Though her late conversation wit
#  can never hope to feel or inspire affection again , and if her home be uncomfo
# m of the sense , elegance , mutual affection , and domestic comfort of the fami
# , and which recommended him to her affection beyond every thing else . His soci
# ween the parties might forward the affection of Mr . Willoughby , an equally st
#  the most pointed assurance of her affection . Elinor could not be surprised at
# ...

# %%
text3.concordance('lived')
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# ...

# %%
text4.concordance('nation')
# Out:
# Displaying 25 of 316 matches:
#  to the character of an independent nation seems to have been distinguished by
# f Heaven can never be expected on a nation that disregards the eternal rules o
# first , the representatives of this nation , then consisting of little more th
# , situation , and relations of this nation and country than any which had ever
# , prosperity , and happiness of the nation I have acquired an habitual attachm
# an be no spectacle presented by any nation more pleasing , more noble , majest
# party for its own ends , not of the nation for the national good . If that sol
# tures and the people throughout the nation . On this subject it might become m
# if a personal esteem for the French nation , formed in a residence of seven ye
# f our fellow - citizens by whatever nation , and if success can not be obtaine
# y , continue His blessing upon this nation and its Government and give it all
# ...

# %%
text4.concordance('terror')
# Out:
# Displaying 8 of 8 matches:
# menaces , by fraud or violence , by terror , intrigue , or venality , the Gove
# ameless , unreasoning , unjustified terror which paralyzes needed efforts to c
# ublic seemed frozen by a fatalistic terror , we proved that this is not true .
#  to alter that uncertain balance of terror that stays the hand of mankind ' s
# eans freeing all Americans from the terror of runaway living costs . All must
# still . They fuel the fanaticism of terror . And they torment the lives of mil
# d maintain a strong defense against terror and destruction . Our children will
# k to advance their aims by inducing terror and slaughtering innocents , we say

# %%
text4.concordance('god')
# Out:
# Displaying 25 of 108 matches:
# eliance on the protection of Almighty God , I shall forthwith commence the duti
# humble , acknowledged dependence upon God and His overruling providence . We ha
# great office I must humbly invoke the God of our fathers for wisdom and firmnes
# d the same Bible and pray to the same God , and each invokes His aid against th
# hat any men should dare to ask a just God ' s assistance in wringing their brea
# offenses which , in the providence of God , must needs come , but which , havin
# butes which the believers in a living God always ascribe to Him ? Fondly do we
# war may speedily pass away . Yet , if God wills that it continue until all the
# r all , with firmness in the right as God gives us to see the right , let us st
# the prayers of the nation to Almighty God in behalf of this consummation . Fell
# r , they have " followed the light as God gave them to see the light ." They ar
# ...

# %% [markdown]
# A concordance permits us to see words in context. For example, we saw that monstrous occurred in contexts such as the ___ pictures and a ___ size . What other words appear in a similar range of contexts? We can find out by appending the term similar to the name of the text in question, then inserting the relevant word in parentheses:

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %% [markdown]
# Observe that we get different results for different texts one with positive connotations, and the other as an intensifier like the word very.

# %% [markdown]
# common_contexts allows us to examine just the contexts that are shared by two or more words. We have to enclose these words by square brackets as well as parentheses, and separate them with a comma:

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text3.similar("lived")
# Out:
# went took dwelt builded

# %%
text4.similar("lived")
# Out:
# been thence trade learned stolen

# %%
text4.common_contexts(["lived", "been"])
# Out:
# have_standing have_too

# %% [markdown]
#  we can also determine the location of a word in the text: how many words from the beginning it appears. This positional information can be displayed using a dispersion plot. Each stripe represents an instance of a word, and each row represents the entire text.

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America", "liberty", "constitution"])

# %% [markdown]
# generating some random text in the various styles we have just seen

# %%
text3.generate('words')

# %% [markdown]
# # Counting vocabularly

# %% [markdown]
# finding out the length of a text from start to finish, in terms of the words and punctuation symbols that appear.

# %%
len(text3) # text3 is Genesis
# Out:
# 44764

# %% [markdown]
# Genesis has 44,764 words and punctuation symbols, or "tokens."

# %% [markdown]
# A token is the technical name for a sequence of characters — such as hairy, his, or :) — that we want to treat as a group. When we count the number of tokens in a text, say, the phrase to be or not to be, we are counting occurrences of these sequences. Thus, in our example phrase there are two occurrences of to, two of be, and one each of or and not. But there are only four distinct vocabulary items in this phrase. How many distinct words does the book of Genesis contain?

# %% [markdown]
# The vocabulary of a text is just the set of tokens that it uses, since in a set, all duplicates are collapsed together

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
len(set(text3))
# Out:
# 2789

# %% [markdown]
# Although it has 44,764 tokens, this book has only 2,789 distinct words, or "word types." A word type is the form or spelling of the word independently of its specific occurrences in a text — that is, the word considered as a unique item of vocabulary. Our count of 2,789 items will include punctuation symbols, so we will generally call these unique items types instead of word types, to encapsualte word and punctuation as whole in general.

# %% [markdown]
# let's calculate a measure of the lexical richness of the text. The next example shows us that the number of distinct words is just 6% of the total number of words, or equivalently that each word is used 16 times on average

# %%
print(round(((len(set(text3)) / len(text3)) * 100 ), 0), "%") # n.o unique items / n.o items
# Out:
# 6.0 %

# %%
6 * 16 # just less than 100%
# Out:
# 96

# %% [markdown]
# We can count how often a word occurs in a text, and compute what percentage of the text is taken up by a specific word

# %%
text3.count("smote")
# Out:
# 5

# %%
print(100 * (text4.count('a') / len(text4)), "%")
# Out:
# 1.457973123627309 %

# %%
print(text5.count("lol"))
print(100 * (text5.count("lol") / len(text5)), "%")
# Out:
# 704
# 1.5640968673628082 %

# %% [markdown]
# functions created in order to just input text and not write more lines of code

# %%
def lexical_diversity(text):
  return len(set(text)) / len(text)

def percentage(count, total):
  return 100 * count / total

# %%
lexical_diversity(text3)
# Out:
# 0.06230453042623537

# %%
lexical_diversity(text5)
# Out:
# 0.13477005109975562

# %%
percentage(4, 5)
# Out:
# 80.0

# %%
percentage(text4.count('a'), len(text4))
# Out:
# 1.457973123627309

# %% [markdown]
# # Texts as lists of words

# %% [markdown]
# for our purposes, we will think of a text as nothing more than a sequence of words and punctuation.

# %%
sent1 = ["Call", "me", "Ishmael", "."]
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
lexical_diversity(sent1) # as the are a total of 4 words and 4 unique words in the text so 4/4 = 1
# Out:
# 1.0

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
ex1 = ["Monty", "Python", "and", "the", "Holy", "Grail"]
sorted(ex1)
# Out:
# ['Grail', 'Holy', 'Monty', 'Python', 'and', 'the']

# %%
len(set(ex1))
# Out:
# 6

# %%
ex1.count('the')
# Out:
# 1

# %% [markdown]
# Indexing

# %%
text4[173], text4.index('awaken') # inverse of each other
# Out:
# ('awaken', 173)

# %% [markdown]
# # Variables

# %% [markdown]
# often use variables to hold intermediate steps of a computation, especially when this makes the code easier to follow.

# %%
vocab = set(text1)
vocab
# Out:
# {'JOB',
#  'tat',
#  'stacked',
#  'balmed',
#  'abiding',
#  'keen',
#  'Congo',
#  'proceedings',
#  'tables',
#  'winks',
#  'sunniest',
#  'boasts',
#  'Port',
#  'excepting',
#  'Far',
#  'Entering',
#  'Gay',
#  'involutions',
#  'crowing',
#  'forget',
#  'Ezekiel',
#  'christenings',
#  'presumption',
#  'inhabitant',
#  'respectively',
#  'duellist',
#  'The',
#  'inspectingly',
#  'astonished',
#  'fluid',
#  'semicircle',
#  'volunteered',
#  'schooner',
#  'mothered',
#  'exceeds',
#  'lent',
#  'random',
#  'above',
#  'lingering',
#  '1671',
#  'BENNETT',
#  'terraqueous',
#  'foe',
#  'Will',
#  'ugly',
#  'lurked',
#  'reigning',
#  'scorbutic',
#  'into',
#  'Patience',
#  'additional',
#  'odorless',
#  'If',
#  'bitterest',
#  'trying',
#  'bunched',
#  'TEENTH',
#  'wolves',
#  'Tolland',
#  'curve',
#  'animals',
#  'vividness',
#  'harboring',
#  'OCTAVO',
#  't',
#  'corkscrew',
#  '[',
#  'doored',
#  'orange',
#  'everything',
#  'remembrances',
#  'busks',
# ...

# %%
vocab_size = len(vocab)
vocab_size
# Out:
# 19317

# %% [markdown]
# # String

# %%
' '.join(['Monty', 'Python'])
# Out:
# 'Monty Python'

# %%
'Monty Python'.split()
# Out:
# ['Monty', 'Python']

# %% [markdown]
# # Simple Stats

# %% [markdown]
# Frequency Distribution tells us the frequency of each vocabulary item in the text. It is a "distribution" because it tells us how the total number of word tokens in the text are distributed across the vocabulary items.

# %% [markdown]
# Let's use a FreqDist to find the 50 most frequent words of Moby Dick

# %%
fdist1 = FreqDist(text1)
print(len(text1)) # total number of items in the text
print(fdist1) # 19317 unique tokens as in frequency column the name column contains each word only once and tallys it up in the freq. column
# Out:
# 260819
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
fdist1.most_common(50) # so commas appears the most in this text and it appears a total of 19713 times in the text
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %% [markdown]
# When we first invoke FreqDist, we pass the name of the text as an argument. We can inspect the total number of words ("outcomes") that have been counted up — 260,819 in the case of Moby Dick. The expression most_common(50) gives us a list of the 50 most frequently occurring types in the text

# %%
fdist1["whale"] # the word whale appears 906 times in this text
# Out:
# 906

# %%
fdist2 = FreqDist(text2)
fdist2 # if not too much data (unique words) shows this
# Out:
# FreqDist({'[': 3,
#           'Sense': 1,
#           'and': 3350,
#           'Sensibility': 1,
#           'by': 737,
#           'Jane': 1,
#           'Austen': 1,
#           '1811': 1,
#           ']': 1,
#           'CHAPTER': 50,
#           '1': 2,
#           'The': 243,
#           'family': 83,
#           'of': 3565,
#           'Dashwood': 252,
#           'had': 969,
#           'long': 100,
#           'been': 440,
#           'settled': 37,
#           'in': 1904,
#           'Sussex': 9,
#           '.': 3975,
#           'Their': 33,
#           'estate': 19,
#           'was': 1846,
#           'large': 26,
#           ',': 9397,
#           'their': 463,
#           'residence': 7,
#           'at': 806,
#           'Norland': 53,
#           'Park': 22,
#           'the': 3861,
#           'centre': 2,
#           'property': 9,
#           'where': 84,
#           'for': 1234,
#           'many': 98,
#           'generations': 1,
#           'they': 428,
# ...

# %% [markdown]
# proportion of the text is taken up with such words can be generated using a cumulative frequency plot for these words

# %%
fdist1.plot(50, cumulative=True)

# %%
120000 / 260819 # the 50 most common (tokens) of the text nearly half the book
# Out:
# 0.4600891806195101

# %% [markdown]
# If the frequent words don't help us, how about the words that occur once only, the so-called hapaxes

# %%
fdist1.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %% [markdown]
# seems that there are too many rare words, and without seeing the context we probably can't guess what half of the hapaxes mean in any case! Since neither frequent nor infrequent words help, we need to try something else.

# %% [markdown]
# # fine grained selection of words

# %% [markdown]
# let's look at the long words of a text; perhaps these will be more characteristic and informative. find the words from the vocabulary of the text that are more than 15 characters long.

# %%
vocab = set(text1)
long_words = [w for w in vocab if len(w) > 15]
sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
vocab = set(text3)
long_words = [w for w in vocab if (len(w) > 3 and len(w) < 6)] # tokens that are more than 3  and less than 6 characters long
sorted(long_words)
# Out:
# ['Abel',
#  'Abide',
#  'Abrah',
#  'Abram',
#  'Accad',
#  'Adah',
#  'Adam',
#  'Admah',
#  'After',
#  'Ajah',
#  'Akan',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Amal',
#  'Ammon',
#  'Anah',
#  'Aner',
#  'Angel',
#  'Aram',
#  'Aran',
#  'Arbah',
#  'Areli',
#  'Arise',
#  'Arodi',
#  'Asher',
#  'Assyr',
#  'Atad',
#  'Avith',
#  'Babel',
#  'Bedad',
#  'Beeri',
#  'Bela',
#  'Belah',
#  'Benam',
#  'Beno',
#  'Beor',
#  'Bera',
#  'Bered',
#  'Bless',
#  'Both',
#  'Bring',
#  'Cain',
#  'Calah',
#  'Cana',
#  'Carmi',
#  'Cast',
#  'Cause',
#  'Come',
#  'Cush',
#  'Dedan',
#  'Dinah',
#  'Drink',
#  'Duke',
#  'Dumah',
#  'Earth',
#  'Ebal',
#  'Eber',
#  'Edar',
#  'Eden',
#  'Edom',
#  'Egypt',
#  'Elah',
#  'Elam',
#  'Elon',
#  'Emins',
#  'Enoch',
#  'Enos',
#  'Ephah',
#  'Epher',
#  'Ephra',
#  'Erech',
#  'Esau',
#  'Esek',
#  'Even',
#  'Every',
#  'Ezbon',
#  'Ezer',
#  'Fear',
#  'Feed',
#  'Fill',
#  'From',
#  'Gaham',
#  'Gatam',
#  'Gaza',
#  'Gera',
# ...

# %% [markdown]
# very long words are often hapaxes (i.e., unique) and perhaps it would be better to find frequently occurring long words. This seems promising since it eliminates frequent short words (e.g., the) and infrequent long words (e.g. antiphilosophists). Here are all words from the chat corpus that are longer than seven characters and occurs more than seven times:

# %%
fdist5 = FreqDist(text5)
vocab5 = set(text5)
sorted(w for w in vocab5 if len(w) > 7 and fdist5[w] > 7)
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %% [markdown]
# # Collocations and Bigrams

# %% [markdown]
# A collocation is a sequence of words that occur together unusually often. Thus red wine is a collocation, whereas the wine is not. A characteristic of collocations is that they are resistant to substitution with words that have similar senses; for example, maroon wine sounds definitely odd.

# %% [markdown]
# To get collacation we get by extracting from a text a list of word pairs, also known as bigrams.

# %%
list(bigrams(['more', 'is', 'said', 'than', 'done']))
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %% [markdown]
# collocations are essentially just frequent bigrams, except that we want to pay more attention to the cases that involve rare words. In particular, we want to find bigrams that occur more often than we would expect based on the frequency of the individual words. To do this we:

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; God
# bless; Chief Justice; Old World; Almighty God; Fellow citizens; Chief
# Magistrate; every citizen; one another; fellow Americans; Indian
# tribes; public debt; foreign nations

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# The collocations that emerge are very specific to the genre of the texts. In order to find red wine as a collocation, we would need to process a much larger body of text.

# %% [markdown]
# # Counting Other things

# %% [markdown]
# we can look at the distribution of word lengths in a text, by creating a FreqDist out of a long list of numbers, where each number is the length of the corresponding word in the text

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
fdist = FreqDist(len(w) for w in text1)
print(fdist) # 19 different token lengths and a total of 260819 tokens
# Out:
# <FreqDist with 19 samples and 260819 outcomes>

# %%
fdist # no token length of 19
# Out:
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %% [markdown]
# We start by deriving a list of the lengths of words in text1, and the FreqDist then counts the number of times each of these occurs. The result is a distribution containing a quarter of a million items, each of which is a number corresponding to a word token in the text. But there are at most only 19 distinct items being counted, the numbers 1 through 19, because there are only 19 different word lengths. I.e., there are words consisting of just one character, two characters, ..., twenty characters, but none with twenty one or more characters or nineteen. One might wonder how frequent the different lengths of word are (e.g., how many words of length four appear in the text, are there more words of length five than length four, etc). We can do this as follows

# %%
fdist.most_common()
# Out:
# [(3, 50223),
#  (1, 47933),
#  (4, 42345),
#  (2, 38513),
#  (5, 26597),
#  (6, 17111),
#  (7, 14399),
#  (8, 9966),
#  (9, 6428),
#  (10, 3528),
#  (11, 1873),
#  (12, 1053),
#  (13, 567),
#  (14, 177),
#  (15, 70),
#  (16, 22),
#  (17, 12),
#  (18, 1),
#  (20, 1)]

# %%
fdist.max()
# Out:
# 3

# %%
fdist[3] # dictionary, accessing the value via its key
# Out:
# 50223

# %%
fdist.freq(3)
# Out:
# 0.19255882431878046

# %% [markdown]
# From this we see that the most frequent word length is 3, and that words of length 3 account for roughly 50,000 (or 20%) of the words making up the book

# %%
print(sorted(w for w in set(text7) if '-' in w and 'index' in w)) # 1)
print(sorted(wd for wd in set(text3) if wd.istitle() and len(wd) > 10)) # 2
print(sorted(w for w in set(sent7) if not w.islower())) # 3
print(sorted(t for t in set(text2) if 'cie' in t or 'cei' in t)) # 4
# Out:
# ['Stock-index', 'index-arbitrage', 'index-fund', 'index-options', 'index-related', 'stock-index']
# ['Abelmizraim', 'Allonbachuth', 'Beerlahairoi', 'Canaanitish', 'Chedorlaomer', 'Girgashites', 'Hazarmaveth', 'Hazezontamar', 'Ishmeelites', 'Jegarsahadutha', 'Jehovahjireh', 'Kirjatharba', 'Melchizedek', 'Mesopotamia', 'Peradventure', 'Philistines', 'Zaphnathpaaneah']
# [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']
# ['ancient', 'ceiling', 'conceit', 'conceited', 'conceive', 'conscience', 'conscientious', 'conscientiously', 'deceitful', 'deceive', 'deceived', 'deceiving', 'deficiencies', 'deficiency', 'deficient', 'delicacies', 'excellencies', 'fancied', 'insufficiency', 'insufficient', 'legacies', 'perceive', 'perceived', 'perceiving', 'prescience', 'prophecies', 'receipt', 'receive', 'received', 'receiving', 'society', 'species', 'sufficient', 'sufficiently', 'undeceive', 'undeceiving']

# %% [markdown]
# 1.   gives tokens that contain - and the word index
# 2.   gives tokens that are title cased i.e. first characeter is a capital and that the token is > 10
# 3. gives tokens that are not all lowercase
# 4. gives words that have cie or cei

# %%
print(len(text1))
print(len(set(text1)))
print(len(set(word.lower() for word in text1))) # gets rid of duplicate words like this and This
# Out:
# 260819
# 19317
# 17231

# %% [markdown]
# Now that we are not double-counting words like This and this, which differ only in capitalization, we've wiped 2,000 off the vocabulary count! We can go a step further and eliminate numbers and punctuation from the vocabulary count by filtering out any non-alphabetic items:

# %%
len(set(word.lower() for word in text1 if word.isalpha()))
# Out:
# 16948

# %% [markdown]
# # Nested Code Blocks

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']
for xyzzy in sent1:
  if xyzzy.endswith('l') or xyzzy.endswith('.'): # gives only tokens that end with l or .
    print(xyzzy)
# Out:
# Call
# Ishmael
# .

# %%
for token in sent1:
  if token.islower():
    print(token, 'is a lowercase word')
  elif token.istitle():
    print(token, 'is a titlecase word')
  else:
    (token, 'is punctuation')
# Out:
# Call is a titlecase word
# me is a lowercase word
# Ishmael is a titlecase word

# %%
tricky = sorted(w for w in set(text2) if 'cie' in w or 'cei' in w)
for word in tricky:
  print(word, end=' ') # instead of printing a new line, we print a space
# Out:
# ancient ceiling conceit conceited conceive conscience conscientious conscientiously deceitful deceive deceived deceiving deficiencies deficiency deficient delicacies excellencies fancied insufficiency insufficient legacies perceive perceived perceiving prescience prophecies receipt receive received receiving society species sufficient sufficiently undeceive undeceiving
